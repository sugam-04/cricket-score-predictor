# %%
import pandas as pd
import numpy as np
import pickle

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       967    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       967    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       967    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       967    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63999 rows x 8 columns]

# %%
df.iloc[21124]
# Out:
# match_id                        434
# batting_team            New Zealand
# bowling_team            West Indies
# ball                            8.6
# runs                              1
# player_dismissed                  0
# city                Mount Maunganui
# venue                      Bay Oval
# Name: 54, dtype: object

# %%
# # Apne Ko Kya Cahiye 
# Batting Team
# Bowling Team
# Current Run Rate 
# Ground 
# Wickets left
# # Last 5 overs runs scored

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8671
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        3092
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])  #Logic kya lagaya ki initials jo hai naa sabke ko rakh liya,agar true hua toh woh lag jaayega nahi toh cities

# %%
df['city'] = cities

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       967    Sri Lanka    Australia  19.3     1                0
# 122       967    Sri Lanka    Australia  19.4     0                0
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       967    Sri Lanka    Australia  19.6     2                0
# 125       967    Sri Lanka    Australia  19.7     1                0
#
#           city                     venue
# 0    Melbourne  Melbourne Cricket Ground
# 1    Melbourne  Melbourne Cricket Ground
# 2    Melbourne  Melbourne Cricket Ground
# 3    Melbourne  Melbourne Cricket Ground
# 4    Melbourne  Melbourne Cricket Ground
# ..         ...                       ...
# 121    Colombo       R Premadasa Stadium
# 122    Colombo       R Premadasa Stadium
# 123    Colombo       R Premadasa Stadium
# 124    Colombo       R Premadasa Stadium
# 125    Colombo       R Premadasa Stadium
#
# [63999 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       967    Sri Lanka    Australia  19.3     1                0
# 122       967    Sri Lanka    Australia  19.4     0                0
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       967    Sri Lanka    Australia  19.6     2                0
# 125       967    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [63999 rows x 7 columns]

# %%
df['city'].value_counts()
# Out:
# Colombo          4086
# Mirpur           3420
# Johannesburg     3202
# Dubai            3092
# Auckland         2655
#                  ...
# Nairobi           123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: city, Length: 86, dtype: int64

# %%
df['city'].value_counts()[df['city'].value_counts() > 360]   #Matlab kam se kam 3 match jhan huye ho
# Out:
# Colombo              4086
# Mirpur               3420
# Johannesburg         3202
# Dubai                3092
# Auckland             2655
# Cape Town            2246
# London               2106
# Pallekele            2066
# Barbados             2050
# Sydney               1579
# Melbourne            1574
# Durban               1520
# St Lucia             1487
# Wellington           1350
# Lauderhill           1238
# Hamilton             1219
# Manchester           1144
# Abu Dhabi            1099
# Centurion            1065
# Mumbai                995
# Nottingham            991
# Southampton           987
# Mount Maunganui       938
# Chittagong            868
# Kolkata               844
# Lahore                748
# Delhi                 739
# Nagpur                735
# Cardiff               730
# Chandigarh            627
# Adelaide              623
# Bangalore             620
# St Kitts              618
# Christchurch          614
# Trinidad              611
# Brisbane              597
# Hambantota            538
# Dhaka                 513
# Lucknow               504
# Kandy                 501
# Karachi               490
# Birmingham            444
# Napier                380
# Hobart                375
# Rajkot                374
# Harare                372
# Perth                 372
# Chester-le-Street     368
# Bristol               367
# Pune                  365
# Name: city, dtype: int64

# %%
df['city'].value_counts()[df['city'].value_counts() > 360].sum()
# Out:
# 57046

# %%
df['city'].value_counts()[df['city'].value_counts() > 360].shape
# Out:
# (50,)

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 360].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       967    Sri Lanka    Australia  19.3     1                0
# 122       967    Sri Lanka    Australia  19.4     0                0
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       967    Sri Lanka    Australia  19.6     2                0
# 125       967    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [57046 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\1598928411.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']
# C:\Program Files\KMSpico\temp\ipykernel_4376\1598928411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       967    Sri Lanka    Australia  19.3     1                0
# 122       967    Sri Lanka    Australia  19.4     0                0
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       967    Sri Lanka    Australia  19.6     2                0
# 125       967    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [57046 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])                     #Kitna over ka kitna ball
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\1192073022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])                     #Kitna over ka kitna ball
# C:\Program Files\KMSpico\temp\ipykernel_4376\1192073022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       967    Sri Lanka    Australia  19.3     1                0
# 122       967    Sri Lanka    Australia  19.4     0                0
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       967    Sri Lanka    Australia  19.6     2                0
# 125       967    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [57046 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')     #Kitni deliveries phenk chuke hai
df
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\199961722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')     #Kitni deliveries phenk chuke hai
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       967    Sri Lanka    Australia  19.3     1                0
# 122       967    Sri Lanka    Australia  19.4     0                0
# 123       967    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       967    Sri Lanka    Australia  19.6     2                0
# 125       967    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# 1    Melbourne              0    0       2             2
# 2    Melbourne              1    0       3             3
# 3    Melbourne              3    0       4             4
# 4    Melbourne              3    0       5             5
# ..         ...            ...  ...     ...           ...
# 121    Colombo            125   19       3           117
# 122    Colombo            125   19       4           118
# 123    Colombo            125   19       5           119
# 124    Colombo            127   19       6           120
# 125    Colombo            128   19       7           121
#
# [57046 rows x 11 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)   #Kitne out huye hai
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\478743009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)   #Kitne out huye hai
# C:\Program Files\KMSpico\temp\ipykernel_4376\478743009.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Program Files\KMSpico\temp\ipykernel_4376\478743009.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# C:\Program Files\KMSpico\temp\ipykernel_4376\478743009.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# C:\Program Files\KMSpico\temp\ipykernel_4376\478743009.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       967    Sri Lanka    Australia  19.3     1                 8
# 122       967    Sri Lanka    Australia  19.4     0                 8
# 123       967    Sri Lanka    Australia  19.5     0                 9
# 124       967    Sri Lanka    Australia  19.6     2                 9
# 125       967    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  wickets_left
# 0    Melbourne              0    0       1             1            10
# 1    Melbourne              0    0       2             2            10
# 2    Melbourne              1    0       3             3            10
# 3    Melbourne              3    0       4             4            10
# 4    Melbourne              3    0       5             5            10
# ..         ...            ...  ...     ...           ...           ...
# 121    Colombo            125   19       3           117             2
# 122    Colombo            125   19       4           118             2
# 123    Colombo            125   19       5           119             1
# 124    Colombo            127   19       6           120             1
# 125    Colombo            128   19       7           121             1
#
# [57046 rows x 12 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']       #Run Rate Nikalne ka Formula
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\4040219610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']       #Run Rate Nikalne ka Formula

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\3055083752.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df                 #Jaahir si baat hai pehle 5 overs mai aise hi hoga
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       967    Sri Lanka    Australia  19.3     1                 8
# 122       967    Sri Lanka    Australia  19.4     0                 8
# 123       967    Sri Lanka    Australia  19.5     0                 9
# 124       967    Sri Lanka    Australia  19.6     2                 9
# 125       967    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  wickets_left  \
# 0    Melbourne              0    0       1             1            10
# 1    Melbourne              0    0       2             2            10
# 2    Melbourne              1    0       3             3            10
# 3    Melbourne              3    0       4             4            10
# 4    Melbourne              3    0       5             5            10
# ..         ...            ...  ...     ...           ...           ...
# 121    Colombo            125   19       3           117             2
# 122    Colombo            125   19       4           118             2
# 123    Colombo            125   19       5           119             1
# 124    Colombo            127   19       6           120             1
# 125    Colombo            128   19       7           121             1
#
#           crr  last_five
# 0    0.000000        NaN
# 1    0.000000        NaN
# 2    2.000000        NaN
# 3    4.500000        NaN
# 4    3.600000        NaN
# ..        ...        ...
# 121  6.410256       32.0
# 122  6.355932       32.0
# 123  6.302521       32.0
# 124  6.350000       33.0
# 125  6.347107       32.0
#
# [57046 rows x 14 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Program Files\KMSpico\temp\ipykernel_4376\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       967    Sri Lanka    Australia  19.3     1                 8
# 122       967    Sri Lanka    Australia  19.4     0                 8
# 123       967    Sri Lanka    Australia  19.5     0                 9
# 124       967    Sri Lanka    Australia  19.6     2                 9
# 125       967    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  wickets_left  \
# 0    Melbourne              0    0       1             1            10
# 1    Melbourne              0    0       2             2            10
# 2    Melbourne              1    0       3             3            10
# 3    Melbourne              3    0       4             4            10
# 4    Melbourne              3    0       5             5            10
# ..         ...            ...  ...     ...           ...           ...
# 121    Colombo            125   19       3           117             2
# 122    Colombo            125   19       4           118             2
# 123    Colombo            125   19       5           119             1
# 124    Colombo            127   19       6           120             1
# 125    Colombo            128   19       7           121             1
#
#           crr  last_five  balls_left
# 0    0.000000        NaN         119
# 1    0.000000        NaN         118
# 2    2.000000        NaN         117
# 3    4.500000        NaN         116
# 4    3.600000        NaN         115
# ..        ...        ...         ...
# 121  6.410256       32.0           3
# 122  6.355932       32.0           2
# 123  6.302521       32.0           1
# 124  6.350000       33.0           0
# 125  6.347107       32.0           0
#
# [57046 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
final_df
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_4376\3489654261.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 57041    Sri Lanka    Australia    Colombo            125           3
# 57042    Sri Lanka    Australia    Colombo            125           2
# 57043    Sri Lanka    Australia    Colombo            125           1
# 57044    Sri Lanka    Australia    Colombo            127           0
# 57045    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 57041             2  6.410256       32.0     128
# 57042             2  6.355932       32.0     128
# 57043             1  6.302521       32.0     128
# 57044             1  6.350000       33.0     128
# 57045             1  6.347107       32.0     128
#
# [57046 rows x 9 columns]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])         #Shuffle kar diya

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team     city  current_score  balls_left  \
# 38766  West Indies    Australia  Colombo             64          66
# 26245    Sri Lanka     Pakistan   London             32          88
#
#        wickets_left       crr  last_five  runs_x
# 38766             8  7.111111       40.0     205
# 26245             7  6.000000       32.0     138

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       batting_team  bowling_team             city  current_score  balls_left  \
# 28851    Australia    Bangladesh         Barbados             50          65
# 55041      England     Sri Lanka            Delhi             49          74
# 160      Australia     Sri Lanka         Adelaide             60          86
# 19751      England     Australia        Cape Town            133           5
# 46168  West Indies    Bangladesh           Mirpur             56          67
# ...            ...           ...              ...            ...         ...
# 22637  West Indies  South Africa     Johannesburg             31          83
# 426    New Zealand    Bangladesh  Mount Maunganui             54          78
# 3159    Bangladesh     Sri Lanka          Colombo             57          86
# 4301      Pakistan   New Zealand       Wellington             31          78
# 56981    Sri Lanka     Australia          Colombo             64          59
#
#        wickets_left        crr  last_five
# 28851             7   5.454545       22.0
# 55041             9   6.391304       41.0
# 160              10  10.588235       59.0
# 19751             1   6.939130       33.0
# 46168            10   6.339623       26.0
# ...             ...        ...        ...
# 22637             8   5.027027       27.0
# 426               7   7.714286       34.0
# 3159              8  10.058824       48.0
# 4301              6   4.428571       27.0
# 56981             6   6.295082       21.0
#
# [34764 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer            #yeh strings ko convert karne mai madad karega

# %%
from sklearn.preprocessing import OneHotEncoder          #Transforming categorical data into some numbers or integers

# %%
from sklearn.pipeline import Pipeline                    #A machine learning pipeline is a way to codify and automate the workflow it takes to produce a machine learning model. Machine learning pipelines consist of multiple sequential steps that do everything from data extraction and preprocessing to model training and deployment.

# %%
from sklearn.preprocessing import StandardScaler                #yeh saare normal dependencies liye 
from sklearn.ensemble import RandomForestRegressor                  
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,accuracy_score

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))        # It is pronounced as R squared and is also known as the coefficient of determination. It works by measuring the amount of variance in the predictions explained by the dataset.
# Out:
# 0.9911786905240849
# 1.5524086998291295

# %%
pickle.dump(pipe,open('main.pkl','wb'))

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Manchester',
#  'Abu Dhabi',
#  'Centurion',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Cardiff',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Christchurch',
#  'Trinidad',
#  'Brisbane',
#  'Hambantota',
#  'Dhaka',
#  'Lucknow',
#  'Kandy',
#  'Karachi',
#  'Birmingham',
#  'Napier',
#  'Hobart',
#  'Rajkot',
#  'Harare',
#  'Perth',
#  'Chester-le-Street',
#  'Bristol',
#  'Pune']
